# %%
# uv add openai-agents

from dotenv import load_dotenv
from agents import Agent,Runner
load_dotenv()
# Out:
# True

# %%
hello_agent = Agent(
    name="Hello World Agent",  
)

result = await Runner.run(hello_agent, "Hey there! How are you?")

print(result.final_output)
# Out:
# Hello! I’m here and ready to help. How are you doing today?
