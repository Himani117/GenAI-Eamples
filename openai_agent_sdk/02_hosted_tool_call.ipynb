# %% [markdown]
# # TOOLS
#
# **Here we define the tools that the agent can use.**
# 1. Hosted tools
#  - These run on LLM servers alongside the AI model.
#  - OpenAI offers retrieval, web search, and computer use as hosted tools.
# 2. Function-calling tools
#  - You define the Python functions, and the agent can call them as a tool.
#  - Useful for tasks that require specific local context or capabilities.
# 3. Agents as tools
#  - Agents can use other agents as tools.
#  - Allowing Agent to call other agent without handing off to them.

# %%
from dotenv import load_dotenv
from agents import Agent, Runner
from agents import WebSearchTool
load_dotenv()
# Out:
# True

# %%
hello_agent = Agent(
    name="Hello World Agent",  
    tools=[WebSearchTool()],
)

result = await Runner.run(hello_agent, "What is on OpenAI's homepage?")

print(result.final_output)
# Out:
# Here’s what’s currently featured on the OpenAI homepage (openai.com), as of today, Monday, December 15, 2025:
#
# Navigation and Header
# • The top navigation bar provides quick links to key areas: ChatGPT, Sora, API Platform, Research, Safety, For Business, For Developers, Stories, Company, and News, along with an option to log in ([openai.com](https://www.openai.com/)).
#
# Main Content Highlights
# • A prominent headline celebrates “Ten years of OpenAI” with a prompt to “Read Sam’s blog.” This marks the company’s 10th anniversary and links to a major blog post by Sam Altman ([openai.com](https://www.openai.com/)).
# • Featured articles spotlight recent major developments, including:
#   - “Introducing GPT‑5.2” (Product, 12‑minute read)
#   - “Introducing shopping research in ChatGPT” (Product, 5‑minute read)
#   - “Building more with GPT‑5.1‑Codex‑Max” (Product, 7‑minute read) ([openai.com](https://www.openai.com/)).
#
# Latest News Section
# • Key company announcements include:
#   - "Ten years" (December 11, 2025)
#   - Partnership with The Walt Disney Company to bring beloved characters to Sora (December 11, 2025)
#   - Appointment of Denise Dresser as Chief Revenue Officer (December 9, 2025)
#   - OpenAI co‑founding the Agentic AI Foundation (December 9, 2025)
#   - Launching its first OpenAI Certifications courses (December 9, 2025)
#   - Announcement of initial grantees for the People‑First AI Fund (December 3, 2025) ([openai.com](https://www.openai.com/)).
#
# Stories and Research
# • Story highlights include user-focused pieces such as:
#   - “Coding and design with GPT‑5”
#   - “Creative writing with GPT‑5”
#   - “Medical research with GPT‑5” (all dated August 7, 2025) ([openai.com](https://www.openai.com/)).
# • Recent research posts featured:
#   - “How confessions can keep language models honest” (December 3, 2025)
#   - “Understanding neural networks through sparse circuits” (November 13, 2025) ([openai.com](https://www.openai.com/)).
#
# OpenAI for Business and Get-Started Section
# • There are showcases of business use cases, including:
#   - Mirakl’s agentic commerce vision
#   - JetBrains’ AI-driven coding enhancements
#   - Scania’s AI-powered workforce acceleration ([openai.com](https://www.openai.com/)).
# • Finally, a “Get started with ChatGPT” section includes a download button to explore the product ([openai.com](https://www.openai.com/)).
#
# Summary
# The OpenAI homepage currently focuses on highlighting key product releases (notably GPT‑5.2 and shopping research) and major news, including company milestones and partnerships. It also features user stories, research breakthroughs, business applications, and easy access to try ChatGPT directly from the site.
#
# If you’d like a deeper exploration of any section—such as the GPT‑5.2 details, shopping capabilities in ChatGPT, or the Disney partnership—just let me know!
